# %% [markdown]
# # Parsing Annotations into COCO (masks, categories)

# %%
# import some common libraries
import numpy as np
import sys
if '/opt/ros/kinetic/lib/python2.7/dist-packages' in sys.path:
    sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')

import cv2
import random
import os
import numpy as np
import json


from pycocotools.coco import COCO
import glob
import base64
import io
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
from PIL import Image
import pycocotools
from skimage import measure
import json
from IPython.core.display import display, HTML

from wordcloud import WordCloud
pd.set_option('max_colwidth', 300)
matplotlib.rcParams['figure.figsize'] = (20, 7.0)

display(HTML(
    """
    <style>
    .container { width:100% !important; }
    #notebook { letter-spacing: normal !important;; }
    .CodeMirror { font-family: monospace !important; }
    .cm-keyword { font-weight: bold !important; color: #008000 !important; }
    .cm-comment { font-style: italic !important; color: #408080 !important; }
    .cm-operator { font-weight: bold !important; color: #AA22FF !important; }
    .cm-number { color: #080 !important; }
    .cm-builtin { color: #008000 !important; }
    .cm-string { color: #BA2121 !important; }
    </style>
    """
))
# Out:
#     <style>
#     .container { width:100% !important; }
#     #notebook { letter-spacing: normal !important;; }
#     .CodeMirror { font-family: monospace !important; }
#     .cm-keyword { font-weight: bold !important; color: #008000 !important; }
#     .cm-comment { font-style: italic !important; color: #408080 !important; }
#     .cm-operator { font-weight: bold !important; color: #AA22FF !important; }
#     .cm-number { color: #080 !important; }
#     .cm-builtin { color: #008000 !important; }
#     .cm-string { color: #BA2121 !important; }
#     </style>

# %% [markdown]
# * #### Set `mask_annotations_f` to the path of the csv file with batch results form a mturk mask annotation task
# * #### Set `tags_f` to the path of the csv file with batch results form a mturk class labeling task
# * #### Set `out_f` to output annotations file name
# * #### Run All

# %%
tags_f = 'properties_data_habitat_mar2021.csv'
mask_annotations_f = 'masks_habitat_mar2021.csv'
out_f = 'habitat_coco_annos.json'

# %% [markdown]
# ### WordCloud of all category labels

# %%
from collections import OrderedDict
from operator import itemgetter
import re

p = dict()

tags_df = pd.read_csv(tags_f)
tags_df = tags_df.loc[tags_df['Answer.tag1'] != "Picture won't load"]
tags_df = tags_df[1:]

for _, row in tags_df.iterrows():
    if row['Answer.tag1'] != "Picture won't load":
        label = row['Answer.tag1'].lower()
        label =  ' '.join([word for word in label.split() if not re.match("a|the|an|the|to|in|for|of|or|by|with|is|on|that|be", word)])
        if label in p.keys():
            p[label] += 1
        else:
            p[label] = 1
    
od = OrderedDict(sorted(p.items(), key=lambda x:x[1], reverse=True))

## Uncomment to look at raw counts
# print("{:<8} {:<15}".format('Label','Count'))
# for k, v in od.items():
#     print("{:<8} {:<15}".format(k, v))

def makeImage(text):
    wc = WordCloud(background_color="white", max_words=100)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.figure(figsize=(15,15))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

makeImage(od)

# %% [markdown]
# ### Combine similar object classes into one

# %%
# Reduce redunancies - window and windows are the same thing
import krovetz
from fuzzywuzzy import process, fuzz

class LabelIdGenerator:
    def __init__(self):
        self.label_id = dict()
        self.ctr = 1
        self.ks = krovetz.PyKrovetzStemmer()
        
    def get_id_for_label(self, label):
        if label == '':
            return 
        if label in self.label_id.keys():
            return self.label_id[label]
    
        # Check if this label reduces to something already
        if len(label.split()) == 1:
            label = self.ks.stem(label)
#             print("Stemming {}, {}".format(label, self.ks.stem(label)))
        
        b = process.extractOne(label, self.label_id.keys(), scorer=fuzz.token_set_ratio)
#         print("best match for {} : {}".format(label, b))
        
        if b is None or b[1] < 100:
            self.label_id[label] = self.ctr
            self.ctr += 1
            return self.label_id[label]
        else:
            print("{} matched to {}".format(label, b))
            return self.label_id[b[0]]
    
    def get_label_id_dict(self):
        return self.label_id
        

lg = LabelIdGenerator()
for k, v in od.items():
    lg.get_id_for_label(k)

print(lg.get_label_id_dict())
# Out:
# window matched to ('window', 100)
# cabinet matched to ('cabinet', 100)
# kitchen cabinet matched to ('cabinet', 100)
# wooden door matched to ('door', 100)
# dining chair matched to ('chair', 100)
# overhead kitchen cabinet matched to ('cabinet', 100)
# picture matched to ('picture frame', 100)
# kitchen cupboard matched to ('cupboard', 100)
# shower handle matched to ('shower', 100)
# door matched to ('door', 100)
# shower tiles matched to ('shower', 100)
# oven matched to ('microwave oven', 100)
# wooden window matched to ('window', 100)
# slipper chair matched to ('chair', 100)
# white counter matched to ('counter', 100)
# frame matched to ('picture frame', 100)
# overhead kitchen cabinets matched to ('kitchen cabinets', 100)
# {'window': 1, 'door': 2, 'chair': 3, 'counter': 4, 'cabinet': 5, 'wall': 6, 'cupboard': 7, 'painting': 8, 'stove': 9, 'carpet': 10, 'shower': 11, 'picture frame': 12, 'sofa': 13, 'condition': 14, 'floor': 15, 'wallframe': 16, 'dishwasher': 17, 'microwave oven': 18, 'cooking range': 19, 'table': 20, 'man': 21, 'roof': 22, 'couch': 23, 'refrigerator': 24, 'conditioning unit': 25, 'portrait': 26, 'kitchen cabinets': 27, 'doorknob': 28, 'wardrobe': 29, 'washing machine': 30, 'curtain': 31, 'paite': 32, 'picturw frame': 33, 'drawer': 34, 'conditoner': 35, 'scrubbler': 36, 'exhaust hood': 37, 'bookshelf': 38, 'showcase': 39, 'cabinetd': 40, 'condtioner': 41, 'drawers': 42, 'do': 43, 'kitched hood': 44, 'baseboard heater': 45, 'doormate': 46, 'bass': 47, 'vase': 48, 'desk': 49, 'ceiling': 50, 'lighting': 51, 'lamp': 52, 'post': 53, 'washing machined': 54, 'tile': 55, 'paint': 56, 'paintign': 57, 'fridge': 58, 'shelf': 59}

# %% [markdown]
# ## Create COCO Annotations

# %%
def hex_to_rgb(hex):
    hex = hex.lstrip('#')
    hlen = len(hex)
    return tuple(int(hex[i:i+hlen // 3], 16) for i in range(0, hlen,hlen//3))

def decode_png(dat):
    byt = base64.b64decode(str(dat))
    img = Image.open(io.BytesIO(byt))
    return img

def get_filtered_id(labels):
    # Returns IDs for label
    for x in labels:
        return lg.get_id_for_label(x)
    print("No id for {}".format(labels))
    return -1

def close_contour(contour):
    if not np.array_equal(contour[0], contour[-1]):
        contour = np.vstack((contour, contour[0]))
    return contour

def binary_mask_to_polygon(binary_mask, tolerance=0):
    """Converts a binary mask to COCO polygon representation
    Args:
        binaaary_mask: a 2D binary numpy array where '1's represent the object
        tolerance: Maximum distance from original points of polygon to approximated
            polygonal chain. If tolerance is 0, the original coordinate array is returned.
    """
    polygons = []
    # pad mask to close contours of shapes which start and end at an edge
    padded_binary_mask = np.pad(binary_mask, pad_width=1, mode='constant', constant_values=0)
    contours = measure.find_contours(padded_binary_mask, 0.5)
    contours = np.subtract(contours, 1)
    for contour in contours:
        contour = close_contour(contour)
        contour = measure.approximate_polygon(contour, tolerance)
        if len(contour) < 3:
            continue
        contour = np.flip(contour, axis=1)
        segmentation = contour.ravel().tolist()
        # after padding and subtracting 1 we may get -0.5 points in our segmentation 
        segmentation = [0 if i < 0 else i for i in segmentation]
        polygons.append(segmentation)

    return polygons

def get_key(filename, col):
    return filename.replace(".jpg", "") + col.replace("#", "%23") + ".png"

def lookup_tag1(filename, col):
    key = get_key(filename, col)
    labels = []
    properties = set()
    for _, row in tags_df.iterrows():
        url = row['Input.image_url']
        url = url.split('/')[-1]
        if key == url:
#             print(key, url)
            labels.append(row['Answer.tag1'].lower())
            properties.add(row['Answer.tag2'].lower())
            properties.add(row['Answer.tag3'].lower())
    return labels, list(properties)

def select_object_classes(mask, instances, filename):
    # return <mask, label> pairs
    # translate hex color to label 
    masks = []
    print("Selecting objects for file {}".format(filename))
    for d in instances:
        # get name for each hex color
        col = d['color']
        l, p = lookup_tag1(filename, col)
        labels = l if d['label'] == 'Object' else [d['label'].lower()]
        img_c = mask.convert('RGB').copy()
        img = mask.copy()
        for x in range(img.size[0]):
            for y in range(img.size[1]):
                if img_c.getpixel((x,y)) != hex_to_rgb(col):
                    img.putpixel((x,y), 0)

#             print("labels {}".format(labels))
#             img.show()
        masks.append((img, labels, p))
    
    return masks

uniq_id = 1

def make_coco_annotations(mask, category_id, img_id):
    if category_id == -1:
        return {}
    mask = np.array(mask)
    ids = np.unique(mask)[1:]
    masks = mask == ids[:, None, None]
    num_masks = len(ids)
#     print("num_masks", num_masks)
    annotations = []
    global uniq_id
    for i in range(num_masks):
        anno = {}
        binary_mask_encoded = pycocotools.mask.encode(np.asfortranarray(masks[i].astype(np.uint8)))
        anno['bbox'] = pycocotools.mask.toBbox(binary_mask_encoded).tolist()
        anno['segmentation'] = binary_mask_to_polygon(masks[i])
#         mask.encode(np.asarray(masks[i], dtype=np.uint8, order="F"))
        anno['area'] = float(pycocotools.mask.area(binary_mask_encoded))
        anno['iscrowd'] = 0
        anno['category_id'] = category_id
        anno['id'] = uniq_id
        uniq_id += 1
        anno['image_id'] = int(img_id.split('.')[0])
        annotations.append(anno)
        print("image_id", anno['image_id'])
    
    return annotations

def get_default_properties(labels):
    if 'chair' in labels:
        k = 'chair'
        l = ['gray', 'mesh-rear', 'comfortable', 'wheeled', 'moveable']
    elif 'monitor' in labels:
        k = 'monitor'
        l = ['electronic', 'plastic', 'flat', 'shiny', 'rectangle']
    elif 'desk' in labels:
        k = 'desk'
        l = ['solid', 'flat', 'wood', 'white']
    for x in l:
        sp_update(pdict, x)
#     print('k {}, v {}, pdict {}'.format(k,l,pdict))
    return l

files = set()

def convert_turk_annotations_to_coco_v2(results):
    df = pd.read_csv(results)
    df['Answer.annotatedResult.instances'] = df['Answer.annotatedResult.instances'].apply(literal_eval)
    display(df['Input.image_url'].head(2))
    print("Number of rows {}".format(len(df)))
    annotations = []
    ctr = 0
    global uniq_id 
    uniq_id = 1
    # one row per HIT, two rows per image 
    for _, row in df.iterrows():
        ctr = ctr + 1
        mask_anno = row['Answer.annotatedResult.labeledImage.pngImageData']
        instances = row['Answer.annotatedResult.instances']
        filename = str(row['Input.image_url']).split('/')[-1]
        files.add(filename)
        mask_img = decode_png(mask_anno)
        mask_labels = select_object_classes(mask_img.copy(), instances, filename)
        for mask, labels, p in mask_labels:
            if labels:
                annos = make_coco_annotations(mask, get_filtered_id(labels), filename)
                for a in annos:
                    if not p:
                    # FIXME: Add properties to the dataset as well
                        p = get_default_properties(labels)
#                         print("defaults {}".format(p))
#                     a['properties'] = [pdict[x] for x in p]
#                     print("a[prop] {}".format(a["properties"]))
                    print("Label {}, properties {}".format(labels, p))
                for a in annos:
                    annotations.append(a)
        print("Total {} annos until url {}".format(len(annotations), row['Input.image_url']))
#         break
    
    return annotations


tags_df = pd.read_csv(tags_f)
tags_df = tags_df.loc[tags_df['Answer.tag1'] != "Picture won't load"]
annotations = convert_turk_annotations_to_coco_v2(mask_annotations_f)
# Out:
# 0    https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00000.jpg
# 1    https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00060.jpg
# Name: Input.image_url, dtype: object
# Number of rows 95
# Selecting objects for file 00000.jpg
# a chair matched to ('chair', 100)
# image_id 0
# Label ['a chair', 'chair'], properties ['black', 'dark brown', 'sitting', 'thin']
# a chair matched to ('chair', 100)
# image_id 0
# Label ['a chair', 'chair'], properties ['dark colored', 'wooden', 'slim', 'painted']
# Total 2 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00000.jpg
# Selecting objects for file 00060.jpg
# /home/locobotm/anaconda3/envs/locobot_env/lib/python3.7/site-packages/ipykernel_launcher.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# window matched to ('window', 100)
# image_id 60
# Label ['windows', 'window'], properties ['square shape', 'covered by blind', 'beige cloth', 'glass windows']
# image_id 60
# Label ['window', 'windows'], properties ['heat resistant', 'transparent glass', 'white', 'closed']
# image_id 60
# Label ['chair', 'chair'], properties ['man made', 'soft cushion', 'wood', 'metal body']
# image_id 60
# Label ['chair', 'chair'], properties ['white', 'brown', 'hard', 'dark colors']
# image_id 60
# Label ['chair', 'dining chair'], properties ['sitting', 'dark painted', 'comfortable', 'metal body']
# Total 7 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00060.jpg
# Selecting objects for file 00120.jpg
# image_id 120
# Label ['window', 'windows'], properties ['square windows', 'glass windows', 'blind covered', 'closed']
# image_id 120
# Label ['door', 'chair'], properties ['white color', 'chemical resistance', 'soft', 'durable']
# image_id 120
# Label ['chair', 'chair'], properties ['foam', 'wooden', 'sitting', 'durable']
# Total 10 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00120.jpg
# Selecting objects for file 00180.jpg
# image_id 180
# Label ['bass', 'vase'], properties ['plant', 'brown', 'tabletop', 'decoration']
# image_id 180
# Label ['chair', 'chair'], properties ['foam', 'dark colored', 'painted', 'metal']
# Total 12 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00180.jpg
# Selecting objects for file 00240.jpg
# image_id 240
# Label ['window', 'windows'], properties ['rectangular shape', 'metal frame', 'glass', 'closed']
# image_id 240
# Label ['window', 'window'], properties ['small', 'white', 'square shape', 'curtain']
# image_id 240
# Label ['picture frame', 'painting'], properties ['stylish design', 'wooden border', 'bright painted', 'work of art']
# wooden window matched to ('window', 100)
# image_id 240
# Label ['wooden window', 'windows'], properties ['absorbs sound', 'made', 'reduces echoing', 'closed']
# Total 16 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00240.jpg
# Selecting objects for file 00300.jpg
# image_id 300
# Label ['wallframe', 'painting'], properties ['beige framing', 'painting', 'bright colors', 'frame']
# image_id 300
# Label ['window', 'window'], properties ['high quality material', 'glass made', 'white color', 'covered']
# image_id 300
# Label ['window', 'window'], properties ['single', 'white', 'see throught', 'glass']
# image_id 300
# Label ['table', 'chair'], properties ['dark painting', 'wooden', 'white', 'glass']
# image_id 300
# Label ['chair', 'a dining chair'], properties ['sitting', 'armless', 'soft', 'thin']
# Total 21 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00300.jpg
# Selecting objects for file 00360.jpg
# image_id 360
# Label ['painting', 'portrait'], properties ['square shaped', 'wall mounted', 'high positioned', 'bright colored']
# image_id 360
# Label ['lighting', 'lamp'], properties ['usable', 'controlled', 'light', 'switch']
# image_id 360
# Label ['sofa', 'couch'], properties ['wooden legs', 'black couch', 'dark color', 'wood']
# image_id 360
# Label ['chair', 'chair'], properties ['brown', 'hard', 'white', 'wood']
# Total 25 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00360.jpg
# Selecting objects for file 00420.jpg
# picture matched to ('picture frame', 100)
# image_id 420
# Label ['picture', 'a portrait'], properties ['rectangular', 'framed', 'glass', 'decor']
# image_id 420
# Label ['picture frame', 'painting'], properties ['paint', 'square frame', 'wall mounted', 'wood']
# window matched to ('window', 100)
# image_id 420
# Label ['windows', 'windows'], properties ['they have blinds on them.', 'semi-transparent', 'white framing', 'blind covered']
# image_id 420
# Label ['couch', 'a sofa'], properties ['black', 'furniture', 'soft']
# image_id 420
# Label ['window', 'window'], properties ['metal frame', 'white colour', 'glass', 'wood']
# Total 30 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00420.jpg
# Selecting objects for file 00480.jpg
# image_id 480
# Label ['wallframe', 'painting'], properties ['art', 'art object', 'painting', 'frame']
# image_id 480
# Label ['painting', 'picture'], properties ['black framing', 'painting', 'white work of art', 'frame']
# image_id 480
# Label ['window', 'window'], properties ['glass window', 'framed', 'white', 'square window']
# image_id 480
# Label ['sofa', 'sofa'], properties ['black', 'soft', 'dark color', 'wood']
# Total 34 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00480.jpg
# Selecting objects for file 00540.jpg
# image_id 540
# Label ['painting', 'frame'], properties ['art', 'framed', 'picture', 'decor']
# image_id 540
# Label ['window', 'window'], properties ['square window', 'white frame', 'white', 'glass']
# image_id 540
# Label ['picture frame', 'picturw frame'], properties ['rectangular shape', 'wooden', 'black frame', 'artwork']
# image_id 540
# Label ['window', 'window'], properties ['opened', 'glass', 'clear', 'curtained']
# Total 38 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00540.jpg
# Selecting objects for file 00600.jpg
# image_id 600
# Label ['paintign', 'wallframe'], properties ['framed', 'painting', 'square', 'beige framing']
# image_id 600
# Label ['sofa', 'sofa'], properties ['black', 'sitting', 'soft']
# image_id 600
# Label ['picture frame', 'painting'], properties ['white', 'square frame', 'framable', 'wooden frame']
# image_id 600
# Label ['window', 'windows'], properties ['handle', 'brightness', 'glass', 'closed']
# Total 42 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00600.jpg
# Selecting objects for file 00660.jpg
# image_id 660
# Label ['painting', 'picture frame'], properties ['art', 'wooden', 'white framing', 'square shape']
# image_id 660
# Label ['window', 'window'], properties ['framed', 'covered', 'glass', 'wood']
# image_id 660
# Label ['window', 'window'], properties ['white', 'square', 'wood']
# image_id 660
# Label ['painting', 'wallframe'], properties ['frame', 'framed in wood', 'painting', 'horizontal']
# image_id 660
# Label ['wall', 'drawers'], properties ['brown', 'hard', 'sofabed', 'wood']
# Total 47 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00660.jpg
# Selecting objects for file 00720.jpg
# image_id 720
# Label ['picture frame', 'painting'], properties ['white molding', 'glass frame', 'clear', 'square']
# image_id 720
# Label ['sofa', 'couch'], properties ['long', 'leather couch', 'soft', 'brown couch']
# image_id 720
# Label ['chair', 'chair'], properties ['wood carved', 'wooden', 'upright', 'wood']
# Total 50 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00720.jpg
# Selecting objects for file 00780.jpg
# image_id 780
# Label ['painting', 'painting'], properties ['frame', 'framing', 'square', 'beige framing']
# a dining chair matched to ('chair', 100)
# image_id 780
# Label ['a dining chair', 'chair'], properties ['black', 'has a white seat', 'sitting', 'usable']
# a chair matched to ('chair', 100)
# image_id 780
# Label ['a chair', 'chair'], properties ['black', 'it has a white seat', 'hard', 'wood']
# image_id 780
# Label ['chair', 'chair'], properties ['brown', 'wooden', 'soft', 'dark color']
# image_id 780
# Label ['window', 'windows'], properties ['white window frame', 'glass window', 'framed', 'wood']
# Total 55 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00780.jpg
# Selecting objects for file 00840.jpg
# image_id 840
# Label ['picture frame', 'painting'], properties ['white framing', 'wall mounted', 'square shape', 'bright colors']
# Total 56 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00840.jpg
# Selecting objects for file 00900.jpg
# image_id 900
# Label ['window', 'window'], properties ['large glass window', 'square window', 'covered', 'closed']
# image_id 900
# Label ['window', 'windows'], properties ['metal frame', 'sliding channel', 'cloth beige', 'white']
# image_id 900
# Label ['window', 'a window'], properties ['rectangular', 'semi-transparent', 'bright color', 'closed']
# image_id 900
# Label ['wall', 'wall'], properties ['painted wall', 'drywall', 'painted', 'wood']
# Total 60 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00900.jpg
# Selecting objects for file 00960.jpg
# image_id 960
# Label ['door', 'table'], properties ['mirror', 'wood made', 'hard', 'transparent']
# Total 61 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/00960.jpg
# Selecting objects for file 01020.jpg
# Total 61 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01020.jpg
# Selecting objects for file 01080.jpg
# Total 61 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01080.jpg
# Selecting objects for file 01140.jpg
# image_id 1140
# Label ['painting', 'wallframe'], properties ['art', 'framed', 'painting', 'frame']
# image_id 1140
# Label ['wall', 'wall'], properties ['painted', 'grey', 'white', 'bright colors']
# Total 63 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01140.jpg
# Selecting objects for file 01200.jpg
# image_id 1200
# Label ['window', 'window'], properties ['bright', 'opened', 'glass', 'decor']
# a door matched to ('door', 100)
# image_id 1200
# Label ['a door', 'door'], properties ['rectangular', 'detailed', 'white', 'closed']
# Total 65 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01200.jpg
# Selecting objects for file 01260.jpg
# image_id 1260
# Label ['window', 'window'], properties ['2 panes', 'blind covered', 'white frames', 'closed']
# image_id 1260
# Label ['window', 'window'], properties ['large glass window', 'glass window', 'blind covered', 'white blind']
# window matched to ('window', 100)
# image_id 1260
# Label ['windows', 'window'], properties ['glass window', 'square window', 'glass', 'wood']
# Total 68 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01260.jpg
# Selecting objects for file 01320.jpg
# a door matched to ('door', 100)
# image_id 1320
# Label ['a door', 'door'], properties ['wood made', 'it has a knob', 'white', 'closed']
# image_id 1320
# Label ['door', 'door'], properties ['iron', 'wood', 'closed']
# window matched to ('window', 100)
# image_id 1320
# Label ['windows', 'window'], properties ['white framed', 'metal frame', 'white color', 'cloth beige']
# Total 71 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01320.jpg
# Selecting objects for file 01380.jpg
# image_id 1380
# Label ['door', 'door'], properties ['handle', 'painted', 'white', 'knob']
# image_id 1380
# Label ['door', 'door'], properties ['painted', 'panel door', 'white', 'wood door']
# image_id 1380
# Label ['window', 'window'], properties ['open', 'double', 'glass', 'see-throught']
# image_id 1380
# Label ['window', 'window'], properties ['curtain', 'blind beige', 'fabric', 'blind covered']
# Total 75 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01380.jpg
# Selecting objects for file 01440.jpg
# image_id 1440
# Label ['door', 'door'], properties ['wood carved', 'wood panel door', 'white door', 'weak wood']
# wooden door matched to ('door', 100)
# image_id 1440
# Label ['wooden door', 'door'], properties ['high quality wood', 'wood', 'white', 'durable']
# Total 77 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01440.jpg
# Selecting objects for file 01500.jpg
# image_id 1500
# Label ['counter', 'cabinetd'], properties ['usable', 'wood cabinets', 'floor mounted', 'white painted']
# image_id 1500
# Label ['counter', 'cabinet'], properties ['reliable', 'strong', 'white', 'wood']
# image_id 1500
# Label ['window', 'window'], properties ['transparent glass', 'covered', 'high quality metal', 'closed']
# do matched to ('do', 100)
# image_id 1500
# Label ['dor', 'door'], properties ['closed door', 'white painted', 'knob', 'wood']
# image_id 1500
# Label ['cabinet', 'cupboard'], properties ['man made', 'white painted', 'white', 'square']
# Total 82 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01500.jpg
# Selecting objects for file 01560.jpg
# wooden door matched to ('door', 100)
# image_id 1560
# Label ['wooden door', 'door'], properties ['handle black', 'high quality', 'wood', 'durable']
# image_id 1560
# Label ['door', 'door'], properties ['handle', 'wooden door', 'white', 'panel door']
# Total 84 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01560.jpg
# Selecting objects for file 01620.jpg
# image_id 1620
# Label ['door', 'door'], properties ['wooden', 'wood panel door', 'white', 'wood door']
# image_id 1620
# Label ['door', 'door'], properties ['black handle', 'wood panel door', 'wood door', 'closed']
# kitchen cabinet matched to ('cabinet', 100)
# image_id 1620
# Label ['kitchen cabinet', 'counter'], properties ['stylish design', 'white color', 'white', 'durable']
# image_id 1620
# Label ['cabinet', 'counter'], properties ['black top', 'rectangle', 'white']
# Total 88 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01620.jpg
# Selecting objects for file 01680.jpg
# image_id 1680
# Label ['door', 'door'], properties ['wood panel', 'man made', 'wood made', 'white door']
# image_id 1680
# Label ['door', 'door'], properties ['black handle', 'wood panel door', 'white', 'wood door']
# Total 90 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01680.jpg
# Selecting objects for file 01740.jpg
# image_id 1740
# Label ['door', 'door'], properties ['handle', 'detailed', 'wood panel door', 'white door']
# image_id 1740
# Label ['counter', 'island'], properties ['hard', 'white', 'stone', 'wood']
# cabinet matched to ('cabinet', 100)
# image_id 1740
# Label ['cabinets', 'cupboard'], properties ['kitchen cabinets', 'hard', 'wall mounted', 'white']
# Total 93 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01740.jpg
# Selecting objects for file 01800.jpg
# image_id 1800
# Label ['cabinet', 'counter'], properties ['wood', 'white', 'sqaure']
# image_id 1800
# Label ['window', 'window'], properties ['curtain', 'white', 'square', 'glass']
# overhead kitchen cabinets matched to ('kitchen cabinets', 100)
# image_id 1800
# Label ['overhead kitchen cabinets', 'counter'], properties ['wooden', 'wood', 'white', 'best quality']
# image_id 1800
# Label ['cabinet', 'window'], properties ['wooden', 'white', 'wood framing']
# Total 97 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01800.jpg
# Selecting objects for file 01860.jpg
# image_id 1860
# Label ['artwork', 'painting'], properties ['art', 'wall painting', 'painting', 'work of art']
# image_id 1860
# Label ['cupboard', 'overhead kitchen cabinet'], properties ['stylish design', 'high quality wood', 'silver handle', 'closed']
# Total 99 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01860.jpg
# Selecting objects for file 01920.jpg
# a door matched to ('door', 100)
# image_id 1920
# Label ['a door', 'door'], properties ['tall', 'wooden', 'hard', 'white']
# image_id 1920
# Label ['cabinet', 'counter'], properties ['wood', 'white', 'square']
# image_id 1920
# Label ['window', 'window'], properties ['sliding function', 'blind', 'covered', 'heat resistant']
# image_id 1920
# Label ['cupboard', 'cabinets'], properties ['wood cabinets', 'wall mounted', 'white', 'wood painted']
# Total 103 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01920.jpg
# Selecting objects for file 01980.jpg
# image_id 1980
# Label ['counter', 'cabinet'], properties ['white', 'wood made', 'white painted', 'square']
# image_id 1980
# Label ['door', 'door'], properties ['carved', 'painted', 'wood door', 'whitw door']
# image_id 1980
# Label ['window', 'window'], properties ['glass', 'wood', 'white', 'square']
# Total 106 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/01980.jpg
# Selecting objects for file 02040.jpg
# image_id 2040
# Label ['door', 'wooden door'], properties ['handle', 'high quality', 'white', 'durable']
# image_id 2040
# Label ['door', 'door'], properties ['door closed', 'white', 'wood painted', 'square']
# image_id 2040
# Label ['window', 'windows'], properties ['curtain', 'blind', 'covered', 'glass']
# Total 109 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02040.jpg
# Selecting objects for file 02100.jpg
# image_id 2100
# Label ['counter', 'cabinet'], properties ['door', 'white', 'wood']
# image_id 2100
# Label ['wall', 'cabinet'], properties ['hard', 'rectangle', 'white']
# image_id 2100
# Label ['window', 'windows'], properties ['square windows', 'white windows', 'blind beige', 'glass']
# Total 112 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02100.jpg
# Selecting objects for file 02160.jpg
# kitchen cabinet matched to ('cabinet', 100)
# image_id 2160
# Label ['kitchen cabinet', 'cupboard'], properties ['large storage space', 'floor level', 'white colour', 'wood']
# cabinet matched to ('cabinet', 100)
# image_id 2160
# Label ['cabinets', 'counter'], properties ['white cabinets', 'wall mounted', 'white', 'wood']
# image_id 2160
# Label ['counter', 'kitchen cabinets'], properties ['large storage space', 'wooden', 'hard', 'white']
# image_id 2160
# Label ['window', 'window'], properties ['curtain', 'double', 'white', 'seeable']
# Total 116 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02160.jpg
# Selecting objects for file 02220.jpg
# image_id 2220
# Label ['counter', 'cabinet'], properties ['white', 'high positioned', 'square']
# image_id 2220
# Label ['window', 'cabinet'], properties ['handle', 'bright', 'wood', 'closed']
# Total 118 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02220.jpg
# Selecting objects for file 02280.jpg
# image_id 2280
# Label ['cupboard', 'cabinets'], properties ['white cabinets', 'wall mounted', 'white', 'wood']
# image_id 2280
# Label ['counter', 'cabinets'], properties ['floor level', 'top', 'floor cabinets', 'white cabinets']
# a shelf matched to ('shelf', 100)
# image_id 2280
# Label ['a shelf', 'cabinet'], properties ['wooden', 'door', 'white', 'wood']
# Total 121 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02280.jpg
# Selecting objects for file 02340.jpg
# image_id 2340
# Label ['man', 'a man'], properties ['tall', 'handsome', 'average height', 'white']
# image_id 2340
# Label ['cupboard', 'cabinet'], properties ['white', 'square', 'wood']
# Total 123 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02340.jpg
# Selecting objects for file 02400.jpg
# image_id 2400
# Label ['cabinet', 'overhead kitchen cabinet'], properties ['handle', 'door', 'wooden', 'durable']
# cabinet matched to ('cabinet', 100)
# image_id 2400
# Label ['cabinets', 'cupboard'], properties ['high', 'hard', 'white']
# image_id 2400
# Label ['window', 'window'], properties ['glass window', 'bright', 'large window', 'closed']
# image_id 2400
# Label ['kitchen cabinets', 'counter'], properties ['high quality wood', 'white painted', 'lenghty', 'more storage space']
# Total 127 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02400.jpg
# Selecting objects for file 02460.jpg
# image_id 2460
# Label ['man', 'a man'], properties ['man in suit', 'well dressed man', 'white', 'grey haired']
# image_id 2460
# Label ['cupboard', 'wardrobe'], properties ['plastic', 'wood', 'silver handle', 'closed']
# image_id 2460
# Label ['counter', 'drawer'], properties ['floor level', 'hard', 'knob', 'wood']
# image_id 2460
# Label ['washing machined', 'dishwasher'], properties ['high quality', 'low energy consumption', 'controllled', 'washing device']
# white counter matched to ('counter', 100)
# image_id 2460
# Label ['white counter', 'kitchen cupboard'], properties ['cabinet with counter', 'wooden', 'white', 'floor cabinets']
# Total 132 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02460.jpg
# Selecting objects for file 02520.jpg
# image_id 2520
# Label ['stove', 'stove'], properties ['electronic', 'heating device', 'metal', 'attached']
# image_id 2520
# Label ['window', 'window'], properties ['curtain', 'double', 'white painted', 'blind']
# image_id 2520
# Label ['cupboard', 'kitchen cabinet'], properties ['white color', 'wood made', 'wooden', 'white']
# image_id 2520
# Label ['door', 'door'], properties ['white', 'wood panel door', 'square door', 'closed']
# image_id 2520
# Label ['window', 'cupboard'], properties ['white', 'glass', 'decor', 'wood']
# Total 137 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02520.jpg
# Selecting objects for file 02580.jpg
# image_id 2580
# Label ['window', 'windows'], properties ['2 glass panes', 'sqaure shape', 'closed window', 'blind covered']
# image_id 2580
# Label ['cabinet', 'cupboard'], properties ['wall cabinet', 'white', 'wood cabinet', 'wood']
# image_id 2580
# Label ['washing machine', 'dishwasher'], properties ['electronic', 'silver', 'floor mounted dishwasher', 'stainless steel']
# image_id 2580
# Label ['stove', 'microwave oven'], properties ['electric', 'steel', 'oven', 'knob']
# Total 141 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02580.jpg
# Selecting objects for file 02640.jpg
# cabinet matched to ('cabinet', 100)
# image_id 2640
# Label ['cabinets', 'counter'], properties ['metal handle', 'wall mounted', 'white', 'wood']
# image_id 2640
# Label ['door', 'door'], properties ['closed door', 'door to kitchen', 'wood', 'frame']
# image_id 2640
# Label ['stove', 'stove'], properties ['usable', 'electronic', 'fire', 'smoke']
# Total 144 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02640.jpg
# Selecting objects for file 02700.jpg
# oven matched to ('microwave oven', 100)
# image_id 2700
# Label ['oven', 'stove'], properties ['usable', 'stove', 'door', 'electronic']
# image_id 2700
# Label ['cabinet', 'counter'], properties ['door', 'high positioned', 'knob', 'wood']
# image_id 2700
# Label ['window', 'window'], properties ['curtain', 'man made', 'glass', 'wood']
# image_id 2700
# Label ['counter', 'cabinet'], properties ['wallmounted', 'white', 'high positioned']
# image_id 2700
# Label ['door', 'door'], properties ['high quality wood', 'wooden', 'white colour', 'white']
# Total 149 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02700.jpg
# Selecting objects for file 02760.jpg
# image_id 2760
# Label ['cabinet', 'counter'], properties ['high putted', 'white painted', 'white', 'square']
# image_id 2760
# Label ['counter', 'a kitchen cabinet'], properties ['long', 'hard', 'it includes microwave']
# window matched to ('window', 100)
# image_id 2760
# Label ['windows', 'door'], properties ['blind beige', 'wooden', 'white']
# image_id 2760
# Label ['door', 'door'], properties ['white colored door', 'door closed', 'door to kitchen', 'wooden door']
# Total 153 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02760.jpg
# Selecting objects for file 02820.jpg
# image_id 2820
# Label ['cabinet', 'counter'], properties ['metal handles', 'wood made', 'white', 'wood cabinet']
# cabinet matched to ('cabinet', 100)
# image_id 2820
# Label ['cabinets', 'counter'], properties ['white painted', 'wooden cabinets', 'wall mounted', 'white']
# image_id 2820
# Label ['washing machine', 'dishwasher'], properties ['electronic', 'silver', 'stainless steel', 'electric']
# image_id 2820
# Label ['window', 'window'], properties ['curtains', 'covered', 'shade', 'closed']
# image_id 2820
# Label ['cabinet', 'counter'], properties ['floor cabinet', 'keeping', 'wood']
# Total 158 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02820.jpg
# Selecting objects for file 02880.jpg
# cabinet matched to ('cabinet', 100)
# image_id 2880
# Label ['cabinets', 'cupboard'], properties ['kitchen cabinets', 'silver handle', 'wall mounted', 'white']
# Total 159 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02880.jpg
# Selecting objects for file 02940.jpg
# image_id 2940
# Label ['door', 'door'], properties ['handle', 'roomdoor', 'white', 'opened door']
# air conditioning unit matched to ('conditioning unit', 100)
# image_id 2940
# Label ['air conditioning unit', 'air conditioner'], properties ['air purifier', 'wall unit', 'white colored ac unit', 'cooling device']
# Total 161 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/02940.jpg
# Selecting objects for file 03000.jpg
# air conditioning unit matched to ('conditioning unit', 100)
# image_id 3000
# Label ['air conditioning unit', 'air conditioner'], properties ['electronic', 'heating device', 'wall mounted', 'white ac unit']
# image_id 3000
# Label ['cabinet', 'cupboard'], properties ['door', 'reliable', 'strong', 'wood']
# image_id 3000
# Label ['door', 'door'], properties ['wood panel door', 'white door', 'white', 'wood']
# image_id 3000
# Label ['door', 'door'], properties ['wooden', 'strong', 'white', 'durable']
# Total 165 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03000.jpg
# Selecting objects for file 03060.jpg
# image_id 3060
# Label ['window', 'a window'], properties ['rectangular', 'semi-transparent', 'made of metal', 'heavy duty']
# window matched to ('window', 100)
# image_id 3060
# Label ['windows', 'windows'], properties ['wide', 'bright', 'glass', 'semmi-transparent']
# image_id 3060
# Label ['door', 'wooden door'], properties ['cabinet door', 'high quality', 'durable', 'closed']
# image_id 3060
# Label ['wall', 'air conditioner'], properties ['heating', 'ceiling', 'cold', 'tile']
# image_id 3060
# Label ['door', 'door'], properties ['wooden door', 'black handle', 'opened', 'white door']
# image_id 3060
# Label ['chair', 'chair'], properties ['sitting', 'comfortable cushion', 'metal', 'metal body']
# image_id 3060
# Label ['chair', 'chair'], properties ['sitting', 'high quality metal body', 'soft cushion', 'metal made']
# Total 172 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03060.jpg
# Selecting objects for file 03120.jpg
# image_id 3120
# Label ['air conditioner', 'air condtioner'], properties ['white color', 'wallmounted', 'wall mounted', 'white']
# image_id 3120
# Label ['chair', 'chair'], properties ['good quality cushion', 'sitting', 'metal made', 'metal body']
# image_id 3120
# Label ['chair', 'a chair'], properties ['metal frame', 'comfortable cushion', 'grey', 'it has a big seat']
# Total 175 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03120.jpg
# Selecting objects for file 03180.jpg
# image_id 3180
# Label ['chair', 'chair'], properties ['wood made', 'metal', 'fabric']
# image_id 3180
# Label ['door', 'door'], properties ['closed', 'white', 'square']
# window matched to ('window', 100)
# image_id 3180
# Label ['windows', 'window'], properties ['curtain', 'big', 'see glass', 'glass']
# Total 178 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03180.jpg
# Selecting objects for file 03240.jpg
# image_id 3240
# Label ['chair', 'chair'], properties ['usable', 'heavy duty', 'bright colors', 'metal body']
# image_id 3240
# Label ['window', 'window'], properties ['square shape', 'white color', 'white', 'glass']
# image_id 3240
# Label ['chair', 'chair'], properties ['grey', 'metal', 'brown', 'metal base']
# Total 181 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03240.jpg
# Selecting objects for file 03300.jpg
# image_id 3300
# Label ['chair', 'chair'], properties ['seat', 'metal', 'soft', 'durable']
# image_id 3300
# Label ['chair', 'chair'], properties ['grey chair', 'grey color', 'hard', 'leather chair']
# image_id 3300
# Label ['window', 'window'], properties ['square window', 'glass', 'blind covered', 'white framings']
# image_id 3300
# Label ['window', 'window'], properties ['2 glass windows', 'framed', 'covered', 'glass windows']
# image_id 3300
# Label ['window', 'window'], properties ['blind', 'bright colors', 'glass', 'decor']
# Total 186 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03300.jpg
# Selecting objects for file 03360.jpg
# image_id 3360
# Label ['chair', 'chair'], properties ['upholstered chair', 'floor level', 'metal', 'metal chair']
# image_id 3360
# Label ['chair', 'chair'], properties ['grey chair', 'not being used', 'metal', 'metal legs']
# Total 188 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03360.jpg
# Selecting objects for file 03420.jpg
# window matched to ('window', 100)
# image_id 3420
# Label ['windows', 'window'], properties ['double', 'high', 'opened', 'glass']
# image_id 3420
# Label ['chair', 'chair'], properties ['sitting', 'felxible', 'durable', 'wood']
# image_id 3420
# Label ['roof', 'wall'], properties ['concrete', 'painted', 'white', 'wood']
# Total 191 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03420.jpg
# Selecting objects for file 03480.jpg
# image_id 3480
# Label ['chair', 'chair'], properties ['leather chair', 'metal leg chair', 'sitting', 'metal made']
# Total 192 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03480.jpg
# Selecting objects for file 03540.jpg
# image_id 3540
# Label ['window', 'windows'], properties ['square windows', 'painted', 'covered', 'glass windows']
# Total 193 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03540.jpg
# Selecting objects for file 03600.jpg
# image_id 3600
# Label ['door', 'door'], properties ['wooden door', 'kmob', 'wood', 'white door']
# image_id 3600
# Label ['curtain', 'wall'], properties ['wallpaper', 'window', 'detailed', 'white']
# image_id 3600
# Label ['wall', 'wall'], properties ['curtain', 'detailed', 'silver details', 'paint']
# Total 196 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03600.jpg
# Selecting objects for file 03660.jpg
# image_id 3660
# Label ['stove', 'cooking range'], properties ['metal gloss finish', 'electronic', 'multifunction', 'off']
# Total 197 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03660.jpg
# Selecting objects for file 03720.jpg
# image_id 3720
# Label ['cooking range', 'stove'], properties ['electronic', 'gloss finish', 'multifunction', 'off']
# image_id 3720
# Label ['scrubbler', 'an exhaust hood'], properties ['cone shaped', 'controlled', 'made up of steel', 'silver']
# a kitchen cupboard matched to ('cupboard', 100)
# image_id 3720
# Label ['a kitchen cupboard', 'cupboard'], properties ['big', 'white', 'keeping', 'keep objects']
# kitchen cabinet matched to ('cabinet', 100)
# image_id 3720
# Label ['kitchen cabinet', 'counter'], properties ['white colour', 'silver details', 'wood', 'more storage space']
# Total 201 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03720.jpg
# Selecting objects for file 03780.jpg
# image_id 3780
# Label ['cooking range', 'stove'], properties ['electronic', 'silver', 'multifunction', 'metallic body']
# image_id 3780
# Label ['cabinet', 'cabinets'], properties ['white cabinets', 'door', 'floor cabinets', 'wood']
# image_id 3780
# Label ['wardrobe', 'counter'], properties ['plastic', 'white', 'wood']
# image_id 3780
# Label ['window', 'window'], properties ['double', 'wood', 'glass', 'closed']
# image_id 3780
# Label ['counter', 'kitched hood'], properties ['wood made', 'metal', 'white painted', 'wallmounted']
# image_id 3780
# Label ['air conditioner', 'cabinet'], properties ['electronic', 'door', 'wood', 'cooler']
# Total 207 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03780.jpg
# Selecting objects for file 03840.jpg
# image_id 3840
# Label ['cabinet', 'counter'], properties ['floor cabinet', 'white color', 'wood made', 'carved']
# image_id 3840
# Label ['cabinet', 'counter'], properties ['white', 'white cabinet', 'wood cabinet', 'wood']
# Total 209 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03840.jpg
# Selecting objects for file 03900.jpg
# overhead kitchen cabinet matched to ('cabinet', 100)
# image_id 3900
# Label ['overhead kitchen cabinet', 'cupboard'], properties ['usable', 'large storage space', 'white color', 'keeper']
# a microwave oven matched to ('microwave oven', 100)
# image_id 3900
# Label ['a microwave oven', 'microwave oven'], properties ['rectangular', 'electronic', 'modern design', 'low energy consumption']
# image_id 3900
# Label ['counter', 'dishwasher'], properties ['floor level', 'stainless steel', 'floor mounted', 'wood']
# image_id 3900
# Label ['cabinet', 'counter'], properties ['handle', 'wood made', 'man made', 'wood']
# image_id 3900
# Label ['window', 'windows'], properties ['tall positioned', 'glass windows', '3 windows', 'closed']
# Total 214 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03900.jpg
# Selecting objects for file 03960.jpg
# image_id 3960
# Label ['counter', 'cabinet'], properties ['metal handles', 'floor mounted', 'wood made', 'floor lever']
# image_id 3960
# Label ['stove', 'cooking range'], properties ['auto electric ignition', 'silver', 'black glass', 'multifunction']
# cabinet matched to ('cabinet', 100)
# image_id 3960
# Label ['cabinets', 'cupboard'], properties ['white cabinets', 'silver', 'wall mounted', 'wood']
# image_id 3960
# Label ['cupboard', 'microwave oven'], properties ['floor', 'compact design', 'high quality', 'wood']
# window matched to ('window', 100)
# image_id 3960
# Label ['windows', 'windows'], properties ['opened', 'white painted', 'glass windows', 'large windows']
# Total 219 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/03960.jpg
# Selecting objects for file 04020.jpg
# image_id 4020
# Label ['cupboard', 'cabinet'], properties ['door', 'wood', 'white', 'silver w']
# kitchen cabinet matched to ('cabinet', 100)
# image_id 4020
# Label ['kitchen cabinet', 'cabinet'], properties ['double', 'best in quality', 'white', 'durable']
# image_id 4020
# Label ['dishwasher', 'counter'], properties ['floor mounted', 'painted', 'white', 'grey color']
# image_id 4020
# Label ['refrigerator', 'fridge'], properties ['plastic', 'electronic', 'cooler device', 'eraser']
# Total 223 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04020.jpg
# Selecting objects for file 04080.jpg
# image_id 4080
# Label ['refrigerator', 'post'], properties ['electronic', 'cold', 'wood post', 'grey post']
# Total 224 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04080.jpg
# Selecting objects for file 04140.jpg
# image_id 4140
# Label ['cabinet', 'refrigerator'], properties ['grey cabinet', 'modern design', 'low power consumption', 'wooden cabinet']
# Total 225 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04140.jpg
# Selecting objects for file 04200.jpg
# Total 225 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04200.jpg
# Selecting objects for file 04260.jpg
# Total 225 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04260.jpg
# Selecting objects for file 04320.jpg
# Total 225 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04320.jpg
# Selecting objects for file 04380.jpg
# Total 225 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04380.jpg
# Selecting objects for file 04440.jpg
# image_id 4440
# Label ['door', 'wall'], properties ['white wall', 'painted', 'black handle', 'white details']
# image_id 4440
# Label ['door', 'door'], properties ['handle', 'floor level', 'wooden', 'white']
# image_id 4440
# Label ['door', 'door'], properties ['square door', 'white door', 'white', 'closed']
# image_id 4440
# Label ['shower', 'carpet'], properties ['hairy', 'tile', 'fluffy', 'drain']
# Total 229 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04440.jpg
# Selecting objects for file 04500.jpg
# image_id 4500
# Label ['door', 'door'], properties ['cabinet door', 'white color', 'closed', 'chemical resistant']
# image_id 4500
# Label ['carpet', 'doormate'], properties ['grey', 'cotton', 'soft', 'bright colored']
# Total 231 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04500.jpg
# Selecting objects for file 04560.jpg
# image_id 4560
# Label ['door', 'door'], properties ['black', 'white color', 'door portion', 'handle']
# door matched to ('door', 100)
# image_id 4560
# Label ['doors', 'wall'], properties ['wall section', 'white color', 'black handle', 'opened']
# image_id 4560
# Label ['floor', 'carpet'], properties ['hairy', 'grey', 'light grey', 'made up of tiles']
# image_id 4560
# Label ['wall', 'door'], properties ['white colour', 'closed', 'interior wall', 'wood']
# Total 235 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04560.jpg
# Selecting objects for file 04620.jpg
# image_id 4620
# Label ['floor', 'carpet'], properties ['grey', 'soft', 'carpet']
# Total 236 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04620.jpg
# Selecting objects for file 04680.jpg
# image_id 4680
# Label ['paint', 'wall'], properties ['art', 'work of art', 'ceramic', 'tile']
# Total 237 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04680.jpg
# Selecting objects for file 04740.jpg
# image_id 4740
# Label ['carpet', 'shower tiles'], properties ['long', 'sensible', 'flooe tiles', 'small tiles']
# Total 238 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04740.jpg
# Selecting objects for file 04800.jpg
# image_id 4800
# Label ['carpet', 'shower'], properties ['flurry', 'soft', 'drain', 'tile']
# Total 239 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04800.jpg
# Selecting objects for file 04860.jpg
# image_id 4860
# Label ['shower', 'wall'], properties ['wall', 'wood', 'man made', 'tile']
# image_id 4860
# Label ['carpet', 'shower'], properties ['furry', 'soft', 'drain', 'tile']
# Total 241 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04860.jpg
# Selecting objects for file 04920.jpg
# image_id 4920
# Label ['wall', 'chair'], properties ['seat', 'hard', 'wood', 'durable']
# image_id 4920
# Label ['table', 'chair'], properties ['brown color', 'wood', 'man made', 'metal base']
# image_id 4920
# Label ['chair', 'cabinet'], properties ['carved', 'white cabinet', 'wood cabinet', 'wood']
# image_id 4920
# Label ['ceiling', 'roof'], properties ['long', 'strong', 'white', 'square']
# Total 245 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04920.jpg
# Selecting objects for file 04980.jpg
# image_id 4980
# Label ['floor', 'floor'], properties ['coated', 'cold', 'ceramic', 'wood']
# image_id 4980
# Label ['wall', 'wall'], properties ['white wall', 'drywall', 'hard', 'white']
# image_id 4980
# Label ['roof', 'cupboard'], properties ['esily taken', 'painted', 'stable', 'white']
# Total 248 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/04980.jpg
# Selecting objects for file 05040.jpg
# image_id 5040
# Label ['doorknob', 'shower'], properties ['cleaning', 'wet', 'metal', 'attached']
# Total 249 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05040.jpg
# Selecting objects for file 05100.jpg
# shower handle matched to ('shower', 100)
# image_id 5100
# Label ['shower handle', 'shower'], properties ['water', 'black object', 'metal', 'grey color']
# Total 250 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05100.jpg
# Selecting objects for file 05160.jpg
# image_id 5160
# Label ['shower', 'doorknob'], properties ['water', 'wet', 'metal', 'brown']
# image_id 5160
# Label ['wall', 'wall'], properties ['paint', 'man made', 'white', 'covered']
# Total 252 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05160.jpg
# Selecting objects for file 05220.jpg
# image_id 5220
# Label ['shower', 'door'], properties ['wet', 'rectangle', 'white', 'off']
# shower handle matched to ('shower', 100)
# image_id 5220
# Label ['shower handle', 'shower'], properties ['heating', 'black object', 'metal', 'grey handle']
# Total 254 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05220.jpg
# Selecting objects for file 05280.jpg
# image_id 5280
# Label ['carpet', 'floor'], properties ['patterns', 'flurry', 'cottony', 'floor tiles']
# Total 255 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05280.jpg
# Selecting objects for file 05340.jpg
# image_id 5340
# Label ['bookshelf', 'a showcase'], properties ['black', 'black bookshelf', 'thin', 'wood shelving']
# image_id 5340
# Label ['chair', 'table'], properties ['sitting', 'brown', 'wood made', 'metal']
# Total 257 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05340.jpg
# Selecting objects for file 05400.jpg
# image_id 5400
# Label ['wall', 'wall'], properties ['white wall', 'drywall', 'painted', 'wood']
# image_id 5400
# Label ['door', 'door'], properties ['closed', 'black handle', 'white', 'wood']
# Total 259 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05400.jpg
# Selecting objects for file 05460.jpg
# image_id 5460
# Label ['door', 'a door'], properties ['long', 'wooden', 'panel door', 'round door knob']
# image_id 5460
# Label ['tile', 'carpet'], properties ['usable', 'bright colored', 'small tiles', 'floor tiles']
# Total 261 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05460.jpg
# Selecting objects for file 05520.jpg
# image_id 5520
# Label ['door', 'door'], properties ['rectangular shape', 'white color', 'wood', 'painted']
# image_id 5520
# Label ['chair', 'a chair'], properties ['patterned', 'white and yellow', 'soft', 'beige']
# image_id 5520
# Label ['desk', 'chair'], properties ['sitting', 'brown', 'dark colored', 'wood']
# image_id 5520
# Label ['chair', 'chair'], properties ['metal base', 'soft', 'white', 'white chair']
# image_id 5520
# Label ['wall', 'wall'], properties ['concrete', 'white', 'beige']
# Total 266 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05520.jpg
# Selecting objects for file 05580.jpg
# paite matched to ('paite', 100)
# image_id 5580
# Label ['paiting', 'painting'], properties ['artwork', 'wall mounted', 'work of art', 'bright colors']
# a baseboard heater matched to ('baseboard heater', 100)
# image_id 5580
# Label ['a baseboard heater', 'air conditioning unit'], properties ['long', 'wall mounted', 'white', 'white ac unit']
# image_id 5580
# Label ['chair', 'chair'], properties ['cushion', 'two color cloth', 'fabric', 'multicolor']
# a chair matched to ('chair', 100)
# image_id 5580
# Label ['a chair', 'chair'], properties ['armless', 'white', 'wood']
# Total 270 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05580.jpg
# Selecting objects for file 05640.jpg
# image_id 5640
# Label ['door', 'door'], properties ['opened door', 'room door', 'decor', 'wood']
# a slipper chair matched to ('chair', 100)
# image_id 5640
# Label ['a slipper chair', 'chair'], properties ['armless', 'white', 'soft']
# air conditoner matched to ('conditoner', 100)
# image_id 5640
# Label ['air conditoner', 'air conditioner'], properties ['electric', 'wall mounted', 'easy to use', 'given cool air']
# image_id 5640
# Label ['artwork', 'painting'], properties ['art', 'wall mounted painting', 'made', 'painting']
# Total 274 annos until url https://locobot-bucket.s3-us-west-2.amazonaws.com/ActiveVisionDatasets/habitat_turk_data/05640.jpg

# %%
# add categories and images dict 
categories = []
cat_ids = lg.get_label_id_dict()
for cat, _id in cat_ids.items():
    if cat:
        categories.append(
            {
                "id": _id,
                "name": cat,
                "supercategory": cat,
            }
        )

images = []
for x in files:
    images.append(
        {
            'file_name': x,
            'id': int(x.split('.')[0]),
            'height': 512,
            'width': 512,
        }
    )

info = {
    "year": 2021, 
    "version": 1, 
    "description": "habitat", 
}

license = {
    "name": "MIT License"
}

# %%
anns = {
    'annotations': annotations, 
    'categories': categories, 
    'images': images,
    'info': info,
    'license': license,
}
with open(out_f, 'w') as fp:
    json.dump(anns, fp)

# %% [markdown]
# ## Test / sanity-check annotations

# %%
from pycocotools.coco import COCO
import skimage.io as io
import matplotlib
import matplotlib.pyplot as plt
import os
import random

images_folder = '/home/locobotm/AVD/habitat_turk_data/'

# Load COCO annotations
coco = COCO(out_f)
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!

# %%
imgIds = coco.getImgIds()
imgs = coco.loadImgs(random.choices(imgIds, k=5))

for x in imgs:
    I = io.imread(os.path.join(images_folder, x['file_name']))
    plt.axis('off')
    plt.imshow(I)
    annIds = coco.getAnnIds(imgIds=[x['id']])
    anns = coco.loadAnns(annIds)
    coco.showAnns(anns, draw_bbox=True)
    plt.show()
