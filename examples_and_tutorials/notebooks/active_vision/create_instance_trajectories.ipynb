# %%
import os
import matplotlib.pyplot as plt
import cv2
from IPython.display import Video
import json
import numpy as np


replica_root = '/datasets01/replica/061819/18_scenes'
habitat_semantic_json = os.path.join(replica_root, 'apartment_0', 'habitat', 'info_semantic.json')
#         habitat_semantic_json = os.path.join(self.sjr, scene + '_info_semantic.json')
#         print(f"Using habitat semantic json {habitat_semantic_json}")
with open(habitat_semantic_json, "r") as f:
    hsd = json.load(f)
    
# print(hsd['classes'])
id_to_class_dict = {}
for x in hsd['classes']:
    id_to_class_dict[x['id']] = x['name']


def get_maximal_relevant_id_in_view(x, traj_path):
    image_id = int(x.split('.')[0])
#     print(f'image_id {image_id}')
    
    seg = os.path.join(traj_path, 'seg')
    prop_path = os.path.join(seg, "{:05d}.npy".format(image_id))
    annot = np.load(prop_path).astype(np.uint32)
    
    ans = -1
    maxarea = 0
    for x in np.unique(annot):
        if x in ids_we_care_about:
            binary_mask = (annot == x).astype(np.int32)
            area = binary_mask.sum()
            
            # check if mask is in view
            if binary_mask[:10,:].any() or binary_mask[:,:10].any() or binary_mask[:,-10:].any() or binary_mask[-10:,:].any():
                continue
            
            if area > maxarea and area > 1000:
                maxarea = area
                ans = x
    return ans
    
    
from shutil import copyfile, rmtree
import json
import os
import matplotlib.pyplot as plt
import cv2

def acopyjson(a, b, r):
    with open(a, "r") as f:
        dat = json.load(f)
        
    dat2 = {}
    
    if os.path.isfile(b):
        with open(b, "r") as f:
            dat2 = json.load(f)
    
    ctr = 0
    for x in range(r[0], r[1]+1):
        dat2.update({ctr: dat[str(x)]})
        ctr += 1
        
    with open(b, "w") as fp:
        json.dump(dat2, fp)


def acopydir(a, b, ext, r):
#     print(f'acopydir {r}')
    if not os.path.isdir(b):
        os.makedirs(b)    
    ctr = 0
    for x in range(r[0], r[1]+1):
        f = "{:05d}{}".format(x, ext)
#         print(f)
        copyfile(os.path.join(a,f), os.path.join(b,"{:05d}{}".format(ctr, ext)))
        ctr += 1
    
ids_we_care_about = [243,404,196,133,170] #[404,196,172,243,133,129,170]

from collections import defaultdict
    
def is_instance_in_view(traj_path, instance, img_id):
    seg = os.path.join(traj_path, 'seg')
    prop_path = os.path.join(seg, "{:05d}.npy".format(img_id))
    annot = np.load(prop_path).astype(np.uint32)
    
    if instance in np.unique(annot):
        mask = (annot == instance).astype(np.int32)
        if mask.sum() > 1000:
            return True
        
    return False
    
def vis(img_dir):
    # view 50 images from traj_out
    imgs = os.listdir(img_dir)
    n = len(imgs) 
    ctr = 0
    rows = n/5
    for x in range(int(rows)):
        fig, axs = plt.subplots(1, 5, figsize=(10,4), dpi=80)
        for y in range(5):
            axs[y].imshow(cv2.cvtColor(cv2.imread(os.path.join(img_dir, imgs[ctr])), cv2.COLOR_BGR2RGB))
            axs[y].set_title(imgs[ctr])
            ctr+=1
        plt.show()
      
def save_traj(start, end, traj_dir, inst_id, traj_out):
    print(f'save_traj {start, end}, instance_id {inst_id}, traj_out {traj_out}')
    
    # copy rgb, seg, depth and data.json
    acopydir(os.path.join(traj_dir, 'rgb'), os.path.join(traj_out, 'rgb'), '.jpg', (start,end))
    acopydir(os.path.join(traj_dir, 'depth'), os.path.join(traj_out, 'depth'), '.npy', (start,end))
    acopydir(os.path.join(traj_dir, 'seg'), os.path.join(traj_out, 'seg'), '.npy', (start,end))
    acopyjson(os.path.join(traj_dir, 'data.json'), os.path.join(traj_out, 'data.json'), (start,end))   

def mine_traj(data_dir, traj, pref, out_dir, min_traj_length):
    # mine all trajs for this instance
    traj_path = os.path.join(data_dir, str(traj), pref)
    if os.path.isdir(traj_path):
        rgb = os.path.join(traj_path, 'rgb')
        imgs = os.listdir(rgb)
        
        maximal_id = []
        # 
        for x in range(len(imgs)):
            ncur = get_maximal_relevant_id_in_view(imgs[x], traj_path)
            maximal_id.append(ncur) # neighbors might not be in full view and that's okay
        
        assert len(maximal_id) == len(imgs)
        
        maximal_id = np.asarray(maximal_id)
        
        for instance in ids_we_care_about:
            ictr = 1
            x = 0
            while x < len(imgs):
                if maximal_id[x] == instance:
                    # copy this over as an instance
                    start = x
                    end = x
                    while end < len(maximal_id)-1 and is_instance_in_view(traj_path, instance, end+1):
                        end += 1

                    while start > 0 and is_instance_in_view(traj_path, instance, start-1):
                        start -= 1
                    
                    x = end
                    if end - start > min_traj_length: # min frame length
                        save_traj(start, end, traj_path, instance, os.path.join(out_dir, str(traj), str(instance), str(ictr)))
                        ictr += 1
                    
                x += 1
                              
            print(f'mined {ictr-1} trajectories for instance {instance}')
    
def prep(num_traj, data_dir, out_dir, min_traj_length, pref=''):
    if os.path.isdir(out_dir):
        print(f'rmtree {out_dir}')
        rmtree(out_dir)
        
    os.makedirs(out_dir)
    
    for traj in range(num_traj):   
        mine_traj(data_dir, traj, pref, out_dir, min_traj_length)

# %%
min_traj_length = 20
dd = '/checkpoint/apratik/data/data/apartment_0/default/no_noise/mul_traj_200_combined_2'
od = '/checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories'
prep(5, dd, od, min_traj_length)

# /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_detection_ids_allinone_test_2
# /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_detection_ids_allinone_auto_test_2
# Out:
# rmtree /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories
# save_traj (504, 590), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/1/243/1
# save_traj (1111, 1147), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/1/243/2
# mined 2 trajectories for instance 243
# save_traj (252, 309), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/1/404/1
# save_traj (459, 540), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/1/404/2
# save_traj (1217, 1243), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/1/404/3
# mined 3 trajectories for instance 404
# save_traj (230, 348), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/1/196/1
# mined 1 trajectories for instance 196
# save_traj (578, 640), instance_id 133, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/1/133/1
# mined 1 trajectories for instance 133
# save_traj (546, 575), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/1/170/1
# mined 1 trajectories for instance 170
# save_traj (74, 148), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/243/1
# save_traj (770, 841), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/243/2
# save_traj (997, 1170), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/243/3
# save_traj (2369, 2426), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/243/4
# mined 4 trajectories for instance 243
# save_traj (1, 55), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/404/1
# save_traj (185, 289), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/404/2
# save_traj (660, 795), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/404/3
# save_traj (951, 1004), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/404/4
# mined 4 trajectories for instance 404
# save_traj (273, 372), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/196/1
# save_traj (644, 701), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/196/2
# mined 2 trajectories for instance 196
# save_traj (825, 882), instance_id 133, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/133/1
# mined 1 trajectories for instance 133
# save_traj (768, 822), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/170/1
# save_traj (965, 1022), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/2/170/2
# mined 2 trajectories for instance 170
# save_traj (471, 543), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/243/1
# save_traj (1898, 2110), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/243/2
# mined 2 trajectories for instance 243
# save_traj (336, 499), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/404/1
# save_traj (1458, 1560), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/404/2
# save_traj (1779, 1922), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/404/3
# mined 3 trajectories for instance 404
# save_traj (0, 38), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/196/1
# save_traj (76, 175), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/196/2
# save_traj (349, 401), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/196/3
# save_traj (1498, 1628), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/196/4
# save_traj (1790, 1836), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/196/5
# mined 5 trajectories for instance 196
# save_traj (528, 584), instance_id 133, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/133/1
# save_traj (1380, 1456), instance_id 133, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/133/2
# save_traj (1951, 1972), instance_id 133, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/133/3
# mined 3 trajectories for instance 133
# save_traj (0, 35), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/170/1
# save_traj (469, 525), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/170/2
# save_traj (1896, 1949), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/170/3
# save_traj (1966, 2003), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/3/170/4
# mined 4 trajectories for instance 170
# save_traj (193, 274), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/243/1
# save_traj (790, 866), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/243/2
# save_traj (1997, 2069), instance_id 243, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/243/3
# mined 3 trajectories for instance 243
# save_traj (657, 818), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/404/1
# save_traj (1579, 1665), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/404/2
# save_traj (1894, 2026), instance_id 404, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/404/3
# mined 3 trajectories for instance 404
# save_traj (339, 365), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/196/1
# save_traj (404, 501), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/196/2
# save_traj (671, 722), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/196/3
# save_traj (1621, 1746), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/196/4
# save_traj (1908, 1932), instance_id 196, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/196/5
# mined 5 trajectories for instance 196
# save_traj (849, 906), instance_id 133, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/133/1
# save_traj (1498, 1576), instance_id 133, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/133/2
# save_traj (2055, 2109), instance_id 133, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/133/3
# mined 3 trajectories for instance 133
# save_traj (337, 362), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/170/1
# save_traj (788, 847), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/170/2
# save_traj (1995, 2052), instance_id 170, traj_out /checkpoint/apratik/data/data/apartment_0/default/no_noise/instance_trajectories/4/170/3
# mined 3 trajectories for instance 170

# %% [markdown]
# <img src=vid_path align="center">

# %%
active_data_dir = '/checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/1633991019'
active_out_dir = '/checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories'
prep(5, active_data_dir, active_out_dir, min_traj_length, pref='default')
# Out:
# rmtree /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories
# save_traj (0, 33), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/243/1
# save_traj (110, 190), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/243/2
# mined 2 trajectories for instance 243
# save_traj (37, 104), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/404/1
# save_traj (1111, 1217), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/404/2
# save_traj (1473, 1503), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/404/3
# mined 3 trajectories for instance 404
# save_traj (1194, 1227), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/196/1
# save_traj (1235, 1324), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/196/2
# save_traj (1482, 1515), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/196/3
# mined 3 trajectories for instance 196
# save_traj (966, 1084), instance_id 133, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/133/1
# mined 1 trajectories for instance 133
# save_traj (0, 40), instance_id 170, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/170/1
# save_traj (1146, 1204), instance_id 170, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/1/170/2
# mined 2 trajectories for instance 170
# save_traj (77, 179), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/243/1
# save_traj (229, 255), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/243/2
# save_traj (275, 343), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/243/3
# save_traj (443, 472), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/243/4
# mined 4 trajectories for instance 243
# save_traj (7, 138), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/404/1
# save_traj (181, 225), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/404/2
# save_traj (1235, 1311), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/404/3
# save_traj (1512, 1541), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/404/4
# save_traj (1553, 1607), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/404/5
# mined 5 trajectories for instance 404
# save_traj (0, 31), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/196/1
# save_traj (45, 79), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/196/2
# save_traj (1285, 1360), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/196/3
# save_traj (1521, 1676), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/196/4
# mined 4 trajectories for instance 196
# save_traj (984, 1055), instance_id 133, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/133/1
# save_traj (1100, 1129), instance_id 133, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/133/2
# save_traj (1154, 1226), instance_id 133, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/133/3
# mined 3 trajectories for instance 133
# save_traj (102, 174), instance_id 170, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/170/1
# save_traj (350, 376), instance_id 170, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/170/2
# save_traj (1266, 1295), instance_id 170, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/2/170/3
# mined 3 trajectories for instance 170
# save_traj (453, 571), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/243/1
# mined 1 trajectories for instance 243
# save_traj (2, 36), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/404/1
# save_traj (270, 306), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/404/2
# save_traj (351, 396), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/404/3
# save_traj (439, 473), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/404/4
# mined 4 trajectories for instance 404
# save_traj (0, 24), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/196/1
# save_traj (216, 250), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/196/2
# save_traj (263, 292), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/196/3
# save_traj (366, 456), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/196/4
# mined 4 trajectories for instance 196
# mined 0 trajectories for instance 133
# save_traj (478, 574), instance_id 170, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/3/170/1
# mined 1 trajectories for instance 170
# save_traj (54, 77), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/243/1
# save_traj (800, 885), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/243/2
# save_traj (953, 1132), instance_id 243, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/243/3
# mined 3 trajectories for instance 243
# save_traj (95, 186), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/404/1
# save_traj (210, 359), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/404/2
# save_traj (719, 763), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/404/3
# save_traj (766, 806), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/404/4
# save_traj (810, 850), instance_id 404, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/404/5
# mined 5 trajectories for instance 404
# save_traj (365, 461), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/196/1
# save_traj (727, 787), instance_id 196, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/196/2
# mined 2 trajectories for instance 196
# mined 0 trajectories for instance 133
# save_traj (140, 171), instance_id 170, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/170/1
# save_traj (821, 881), instance_id 170, traj_out /checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/instance_trajectories/4/170/2
# mined 2 trajectories for instance 170
