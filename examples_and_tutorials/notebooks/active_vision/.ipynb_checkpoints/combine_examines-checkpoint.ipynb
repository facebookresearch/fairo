# %%
import os 
import glob 

from shutil import copyfile, rmtree
import json

def acopyjson(a, c):
    with open(a, "r") as f:
        src = json.load(f)
    
    dst = {}
    if os.path.isfile(c):
        with open(c, "r") as f:
            dst = json.load(f)
        
    ctr = len(dst.keys())
    # print(f'before {len(dst.keys()), len(src.keys())}')
    for k, v in src.items():
        dst[ctr] = v
        ctr += 1
    
    # print(f'after {len(dst.keys())}')
    with open(c, "w") as fp:
        json.dump(dst, fp)

def acopydir(a, c, ext):
    if not os.path.isdir(c):
        os.makedirs(c)
    
    fsa = [x for x in glob.glob(os.path.join(a, f'*{ext}'))]
    # print(f'copying {len(fsa)} files from {a} into {c}')
    
    ctr = len(glob.glob(os.path.join(c, f'*{ext}')))
    # print(f'{ctr} files already exist')
    
    for f in fsa:
        fname = "{:05d}{}".format(ctr, ext)
        # print(f'copyfile {fname, os.path.join(c, fname)}')
        copyfile(f, os.path.join(c, fname))
        ctr += 1
    
#     print(f'acopydir {len(fsa), len(fsb)}')
    
    
def combine(ex_list, traj_ab):
    if not os.path.isdir(traj_ab):
        os.makedirs(traj_ab)
    
    # copy over rgb, depth, seg from traj a
    # copy over rgb, d, seg from traj b but with new names 
    for x in ex_list:
        acopydir(os.path.join(x, 'rgb'), os.path.join(traj_ab, 'rgb'), '.jpg')  
        acopydir(os.path.join(x, 'rgb_dbg'), os.path.join(traj_ab, 'rgb_dbg'), '.jpg')  
        acopydir(os.path.join(x, 'depth'), os.path.join(traj_ab, 'depth'), '.npy')
        acopydir(os.path.join(x, 'seg'), os.path.join(traj_ab, 'seg'), '.npy')
        acopyjson(os.path.join(x, 'data.json'), os.path.join(traj_ab, 'data.json'))
    

def combine_all_examines_for_traj(src, dst):
    examines = [os.path.join(src, x) for x in os.listdir(src) if x.isdigit()]
    print(f'{len(examines)} in {src}')
    
    if len(examines) > 1:
        print(f'combining {len(examines)} for {src} into {dst}')
        combine(examines, dst)
        
        # do basic sanity check
        basic_sanity(dst) 


def basic_sanity(traj_path):
    def ll(x, y, ext):
        l = len(glob.glob(os.path.join(x, y, f'*{ext}')))
        print(f'len({x}/{y}) {l}')
        return l
    # load json
    with open(os.path.join(traj_path, 'data.json'), 'r') as f:
        data = json.load(f)
        print(f'data.json {len(data.keys())}')
    assert ll(traj_path, 'rgb', '.jpg') == ll(traj_path, 'seg', '.npy') == ll(traj_path, 'depth', '.npy') == len(data.keys())        

def combine_examines(root_dir, out_dir):
    if not os.path.isdir(out_dir):
        os.makedirs(out_dir)
    
    for x in os.listdir(root_dir):
        if x.isdigit():
            # this is a trajectory that needs all examines combined 
            traj_path = os.path.join(root_dir, x)
            combine_all_examines_for_traj(
                traj_path, 
                os.path.join(out_dir, x)
            )
            
rd = '/checkpoint/apratik/data_dec/'

for x in os.listdir(rd)[:1]:
    cur_dir = os.path.join(rd, x)
    out_dir = os.path.join(rd, 'combined_examines', x)
    print(cur_dir, out_dir)
    print(f'recreating {out_dir}')
    rmtree(out_dir)
    combine_examines(cur_dir, out_dir)
# Out:
# /checkpoint/apratik/data_dec/circle /checkpoint/apratik/data_dec/combined_examines/circle
# recreating /checkpoint/apratik/data_dec/combined_examines/circle
# 19 in /checkpoint/apratik/data_dec/circle/0
# combining 19 for /checkpoint/apratik/data_dec/circle/0 into /checkpoint/apratik/data_dec/combined_examines/circle/0
# data.json 168
# len(/checkpoint/apratik/data_dec/combined_examines/circle/0/rgb) 168
# len(/checkpoint/apratik/data_dec/combined_examines/circle/0/seg) 168
# len(/checkpoint/apratik/data_dec/combined_examines/circle/0/depth) 168
# 1 in /checkpoint/apratik/data_dec/circle/1
# 21 in /checkpoint/apratik/data_dec/circle/2
# combining 21 for /checkpoint/apratik/data_dec/circle/2 into /checkpoint/apratik/data_dec/combined_examines/circle/2
# data.json 129
# len(/checkpoint/apratik/data_dec/combined_examines/circle/2/rgb) 129
# len(/checkpoint/apratik/data_dec/combined_examines/circle/2/seg) 129
# len(/checkpoint/apratik/data_dec/combined_examines/circle/2/depth) 129
# 0 in /checkpoint/apratik/data_dec/circle/3
# 0 in /checkpoint/apratik/data_dec/circle/4
# 31 in /checkpoint/apratik/data_dec/circle/5
# combining 31 for /checkpoint/apratik/data_dec/circle/5 into /checkpoint/apratik/data_dec/combined_examines/circle/5
# data.json 254
# len(/checkpoint/apratik/data_dec/combined_examines/circle/5/rgb) 254
# len(/checkpoint/apratik/data_dec/combined_examines/circle/5/seg) 254
# len(/checkpoint/apratik/data_dec/combined_examines/circle/5/depth) 254
# 25 in /checkpoint/apratik/data_dec/circle/6
# combining 25 for /checkpoint/apratik/data_dec/circle/6 into /checkpoint/apratik/data_dec/combined_examines/circle/6
# data.json 168
# len(/checkpoint/apratik/data_dec/combined_examines/circle/6/rgb) 168
# len(/checkpoint/apratik/data_dec/combined_examines/circle/6/seg) 168
# len(/checkpoint/apratik/data_dec/combined_examines/circle/6/depth) 168
# 1 in /checkpoint/apratik/data_dec/circle/7
# 42 in /checkpoint/apratik/data_dec/circle/8
# combining 42 for /checkpoint/apratik/data_dec/circle/8 into /checkpoint/apratik/data_dec/combined_examines/circle/8
# data.json 223
# len(/checkpoint/apratik/data_dec/combined_examines/circle/8/rgb) 223
# len(/checkpoint/apratik/data_dec/combined_examines/circle/8/seg) 223
# len(/checkpoint/apratik/data_dec/combined_examines/circle/8/depth) 223
# 0 in /checkpoint/apratik/data_dec/circle/9
# 0 in /checkpoint/apratik/data_dec/circle/10
# 24 in /checkpoint/apratik/data_dec/circle/11
# combining 24 for /checkpoint/apratik/data_dec/circle/11 into /checkpoint/apratik/data_dec/combined_examines/circle/11
# data.json 122
# len(/checkpoint/apratik/data_dec/combined_examines/circle/11/rgb) 122
# len(/checkpoint/apratik/data_dec/combined_examines/circle/11/seg) 122
# len(/checkpoint/apratik/data_dec/combined_examines/circle/11/depth) 122
# 1 in /checkpoint/apratik/data_dec/circle/12
# 0 in /checkpoint/apratik/data_dec/circle/13
# 0 in /checkpoint/apratik/data_dec/circle/14
# 22 in /checkpoint/apratik/data_dec/circle/15
# combining 22 for /checkpoint/apratik/data_dec/circle/15 into /checkpoint/apratik/data_dec/combined_examines/circle/15
# data.json 137
# len(/checkpoint/apratik/data_dec/combined_examines/circle/15/rgb) 137
# len(/checkpoint/apratik/data_dec/combined_examines/circle/15/seg) 137
# len(/checkpoint/apratik/data_dec/combined_examines/circle/15/depth) 137
# 0 in /checkpoint/apratik/data_dec/circle/16
# 38 in /checkpoint/apratik/data_dec/circle/17
# combining 38 for /checkpoint/apratik/data_dec/circle/17 into /checkpoint/apratik/data_dec/combined_examines/circle/17
# data.json 263
# len(/checkpoint/apratik/data_dec/combined_examines/circle/17/rgb) 263
# len(/checkpoint/apratik/data_dec/combined_examines/circle/17/seg) 263
# len(/checkpoint/apratik/data_dec/combined_examines/circle/17/depth) 263
# 29 in /checkpoint/apratik/data_dec/circle/18
# combining 29 for /checkpoint/apratik/data_dec/circle/18 into /checkpoint/apratik/data_dec/combined_examines/circle/18
# data.json 181
# len(/checkpoint/apratik/data_dec/combined_examines/circle/18/rgb) 181
# len(/checkpoint/apratik/data_dec/combined_examines/circle/18/seg) 181
# len(/checkpoint/apratik/data_dec/combined_examines/circle/18/depth) 181
# 0 in /checkpoint/apratik/data_dec/circle/19
# 33 in /checkpoint/apratik/data_dec/circle/20
# combining 33 for /checkpoint/apratik/data_dec/circle/20 into /checkpoint/apratik/data_dec/combined_examines/circle/20
# data.json 282
# len(/checkpoint/apratik/data_dec/combined_examines/circle/20/rgb) 282
# len(/checkpoint/apratik/data_dec/combined_examines/circle/20/seg) 282
# len(/checkpoint/apratik/data_dec/combined_examines/circle/20/depth) 282
# 29 in /checkpoint/apratik/data_dec/circle/21
# combining 29 for /checkpoint/apratik/data_dec/circle/21 into /checkpoint/apratik/data_dec/combined_examines/circle/21
# data.json 121
# len(/checkpoint/apratik/data_dec/combined_examines/circle/21/rgb) 121
# len(/checkpoint/apratik/data_dec/combined_examines/circle/21/seg) 121
# len(/checkpoint/apratik/data_dec/combined_examines/circle/21/depth) 121
# 0 in /checkpoint/apratik/data_dec/circle/22
# 0 in /checkpoint/apratik/data_dec/circle/23
# 24 in /checkpoint/apratik/data_dec/circle/24
# combining 24 for /checkpoint/apratik/data_dec/circle/24 into /checkpoint/apratik/data_dec/combined_examines/circle/24
# data.json 218
# len(/checkpoint/apratik/data_dec/combined_examines/circle/24/rgb) 218
# len(/checkpoint/apratik/data_dec/combined_examines/circle/24/seg) 218
# len(/checkpoint/apratik/data_dec/combined_examines/circle/24/depth) 218
# 27 in /checkpoint/apratik/data_dec/circle/25
# combining 27 for /checkpoint/apratik/data_dec/circle/25 into /checkpoint/apratik/data_dec/combined_examines/circle/25
# data.json 150
# len(/checkpoint/apratik/data_dec/combined_examines/circle/25/rgb) 150
# len(/checkpoint/apratik/data_dec/combined_examines/circle/25/seg) 150
# len(/checkpoint/apratik/data_dec/combined_examines/circle/25/depth) 150
# 0 in /checkpoint/apratik/data_dec/circle/26
# 28 in /checkpoint/apratik/data_dec/circle/27
# combining 28 for /checkpoint/apratik/data_dec/circle/27 into /checkpoint/apratik/data_dec/combined_examines/circle/27
# data.json 155
# len(/checkpoint/apratik/data_dec/combined_examines/circle/27/rgb) 155
# len(/checkpoint/apratik/data_dec/combined_examines/circle/27/seg) 155
# len(/checkpoint/apratik/data_dec/combined_examines/circle/27/depth) 155
# 0 in /checkpoint/apratik/data_dec/circle/28
# 0 in /checkpoint/apratik/data_dec/circle/29
# 35 in /checkpoint/apratik/data_dec/circle/30
# combining 35 for /checkpoint/apratik/data_dec/circle/30 into /checkpoint/apratik/data_dec/combined_examines/circle/30
# data.json 225
# len(/checkpoint/apratik/data_dec/combined_examines/circle/30/rgb) 225
# len(/checkpoint/apratik/data_dec/combined_examines/circle/30/seg) 225
# len(/checkpoint/apratik/data_dec/combined_examines/circle/30/depth) 225
# 26 in /checkpoint/apratik/data_dec/circle/31
# combining 26 for /checkpoint/apratik/data_dec/circle/31 into /checkpoint/apratik/data_dec/combined_examines/circle/31
# data.json 161
# len(/checkpoint/apratik/data_dec/combined_examines/circle/31/rgb) 161
# len(/checkpoint/apratik/data_dec/combined_examines/circle/31/seg) 161
# len(/checkpoint/apratik/data_dec/combined_examines/circle/31/depth) 161
# 1 in /checkpoint/apratik/data_dec/circle/32
# 36 in /checkpoint/apratik/data_dec/circle/33
# combining 36 for /checkpoint/apratik/data_dec/circle/33 into /checkpoint/apratik/data_dec/combined_examines/circle/33
# data.json 288
# len(/checkpoint/apratik/data_dec/combined_examines/circle/33/rgb) 288
# len(/checkpoint/apratik/data_dec/combined_examines/circle/33/seg) 288
# len(/checkpoint/apratik/data_dec/combined_examines/circle/33/depth) 288
# 40 in /checkpoint/apratik/data_dec/circle/34
# combining 40 for /checkpoint/apratik/data_dec/circle/34 into /checkpoint/apratik/data_dec/combined_examines/circle/34
# data.json 333
# len(/checkpoint/apratik/data_dec/combined_examines/circle/34/rgb) 333
# len(/checkpoint/apratik/data_dec/combined_examines/circle/34/seg) 333
# len(/checkpoint/apratik/data_dec/combined_examines/circle/34/depth) 333
# 41 in /checkpoint/apratik/data_dec/circle/35
# combining 41 for /checkpoint/apratik/data_dec/circle/35 into /checkpoint/apratik/data_dec/combined_examines/circle/35
# data.json 241
# len(/checkpoint/apratik/data_dec/combined_examines/circle/35/rgb) 241
# len(/checkpoint/apratik/data_dec/combined_examines/circle/35/seg) 241
# len(/checkpoint/apratik/data_dec/combined_examines/circle/35/depth) 241
# 0 in /checkpoint/apratik/data_dec/circle/36
# 0 in /checkpoint/apratik/data_dec/circle/37
# 35 in /checkpoint/apratik/data_dec/circle/38
# combining 35 for /checkpoint/apratik/data_dec/circle/38 into /checkpoint/apratik/data_dec/combined_examines/circle/38
# data.json 182
# len(/checkpoint/apratik/data_dec/combined_examines/circle/38/rgb) 182
# len(/checkpoint/apratik/data_dec/combined_examines/circle/38/seg) 182
# len(/checkpoint/apratik/data_dec/combined_examines/circle/38/depth) 182
# 8 in /checkpoint/apratik/data_dec/circle/39
# combining 8 for /checkpoint/apratik/data_dec/circle/39 into /checkpoint/apratik/data_dec/combined_examines/circle/39
# data.json 36
# len(/checkpoint/apratik/data_dec/combined_examines/circle/39/rgb) 36
# len(/checkpoint/apratik/data_dec/combined_examines/circle/39/seg) 36
# len(/checkpoint/apratik/data_dec/combined_examines/circle/39/depth) 36
# 0 in /checkpoint/apratik/data_dec/circle/40
# 22 in /checkpoint/apratik/data_dec/circle/41
# combining 22 for /checkpoint/apratik/data_dec/circle/41 into /checkpoint/apratik/data_dec/combined_examines/circle/41
# data.json 143
# len(/checkpoint/apratik/data_dec/combined_examines/circle/41/rgb) 143
# len(/checkpoint/apratik/data_dec/combined_examines/circle/41/seg) 143
# len(/checkpoint/apratik/data_dec/combined_examines/circle/41/depth) 143
# 1 in /checkpoint/apratik/data_dec/circle/42
# 24 in /checkpoint/apratik/data_dec/circle/43
# combining 24 for /checkpoint/apratik/data_dec/circle/43 into /checkpoint/apratik/data_dec/combined_examines/circle/43
# data.json 195
# len(/checkpoint/apratik/data_dec/combined_examines/circle/43/rgb) 195
# len(/checkpoint/apratik/data_dec/combined_examines/circle/43/seg) 195
# len(/checkpoint/apratik/data_dec/combined_examines/circle/43/depth) 195
# 0 in /checkpoint/apratik/data_dec/circle/44
# 0 in /checkpoint/apratik/data_dec/circle/45
# 32 in /checkpoint/apratik/data_dec/circle/46
# combining 32 for /checkpoint/apratik/data_dec/circle/46 into /checkpoint/apratik/data_dec/combined_examines/circle/46
# data.json 141
# len(/checkpoint/apratik/data_dec/combined_examines/circle/46/rgb) 141
# len(/checkpoint/apratik/data_dec/combined_examines/circle/46/seg) 141
# len(/checkpoint/apratik/data_dec/combined_examines/circle/46/depth) 141
# 0 in /checkpoint/apratik/data_dec/circle/47
# 25 in /checkpoint/apratik/data_dec/circle/48
# combining 25 for /checkpoint/apratik/data_dec/circle/48 into /checkpoint/apratik/data_dec/combined_examines/circle/48
# data.json 138
# len(/checkpoint/apratik/data_dec/combined_examines/circle/48/rgb) 138
# len(/checkpoint/apratik/data_dec/combined_examines/circle/48/seg) 138
# len(/checkpoint/apratik/data_dec/combined_examines/circle/48/depth) 138
# 0 in /checkpoint/apratik/data_dec/circle/49
# 38 in /checkpoint/apratik/data_dec/circle/50
# combining 38 for /checkpoint/apratik/data_dec/circle/50 into /checkpoint/apratik/data_dec/combined_examines/circle/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-83c099866889> in <module>
#     100     print(f'recreating {out_dir}')
#     101     rmtree(out_dir)
# --> 102     combine_examines(cur_dir, out_dir)
#
# <ipython-input-23-83c099866889> in combine_examines(root_dir, out_dir)
#      89             combine_all_examines_for_traj(
#      90                 traj_path,
# ---> 91                 os.path.join(out_dir, x)
#      92             )
#      93
#
# <ipython-input-23-83c099866889> in combine_all_examines_for_traj(src, dst)
#      62     if len(examines) > 1:
#      63         print(f'combining {len(examines)} for {src} into {dst}')
# ---> 64         combine(examines, dst)
#      65
#      66         # do basic sanity check
#
# <ipython-input-23-83c099866889> in combine(ex_list, traj_ab)
#      51     for x in ex_list:
#      52         acopydir(os.path.join(x, 'rgb'), os.path.join(traj_ab, 'rgb'), '.jpg')
# ---> 53         acopydir(os.path.join(x, 'depth'), os.path.join(traj_ab, 'depth'), '.npy')
#      54         acopydir(os.path.join(x, 'seg'), os.path.join(traj_ab, 'seg'), '.npy')
#      55         acopyjson(os.path.join(x, 'data.json'), os.path.join(traj_ab, 'data.json'))
#
# <ipython-input-23-83c099866889> in acopydir(a, c, ext)
#      37         fname = "{:05d}{}".format(ctr, ext)
#      38         # print(f'copyfile {fname, os.path.join(c, fname)}')
# ---> 39         copyfile(f, os.path.join(c, fname))
#      40         ctr += 1
#      41
#
# ~/.conda/envs/locobot_env/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     119     else:
#     120         with open(src, 'rb') as fsrc:
# --> 121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#     123     return dst
#
# KeyboardInterrupt:

# %%
a# root_dir = '/checkpoint/apratik/data/data/apartment_0/default/no_noise/mul_traj_200'
root_dir = '/checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200'
combine = 2
new_dir = f'/checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200_combined_{combine}'

if not os.path.isdir(new_dir):
    os.makedirs(new_dir)
    
# check valid trajectories
def basic_sanity(traj_path):
    def ll(x, y, ext):
        return len(glob.glob(os.path.join(x, y, f'*{ext}')))
    # TODO: add base_pose sanity check here
    return ll(traj_path, 'rgb', '.jpg') == ll(traj_path, 'seg', '.npy') == ll(traj_path, 'depth', '.npy')

valid_traj = []
for x in range(201):
    traj_path = os.path.join(root_dir, str(x))
    if os.path.isdir(traj_path) and basic_sanity(traj_path):
        valid_traj.append(traj_path)

# %%
from shutil import copyfile
import json

def acopyjson(a, b, c):
    with open(a, "r") as f:
        dat = json.load(f)
        
    with open(b, "r") as f:
        dat2 = json.load(f)
        
    ctr = len(dat.keys())
#     print(f'before {len(dat.keys()), len(dat2.keys())}')
    for k, v in dat2.items():
        dat[ctr] = v
        ctr += 1
    
#     print(f'after {len(dat.keys())}')
    with open(c, "w") as fp:
        json.dump(dat, fp)

def acopydir(a, b, c, ext):
    if not os.path.isdir(c):
        os.makedirs(c)
    
    fsa = [x for x in glob.glob(os.path.join(a, f'*{ext}'))]
    
    ctr = 0
    for f in fsa:
        fname = f.split('/')[-1]
        copyfile(f, os.path.join(c, fname))
        ctr += 1

    fsb = [x for x in glob.glob(os.path.join(b, f'*{ext}'))] 
    for f in fsb:
        fname = "{:05d}{}".format(ctr, ext)
        ctr += 1
        copyfile(f, os.path.join(c, fname))
    
#     print(f'acopydir {len(fsa), len(fsb)}')
    
    
def combine(traj_a, traj_b, traj_ab):
    if not os.path.isdir(traj_ab):
        os.makedirs(traj_ab)
    
    # copy over rgb, depth, seg from traj a
    # copy over rgb, d, seg from traj b but with new names 
    acopydir(os.path.join(traj_a, 'rgb'), os.path.join(traj_b, 'rgb'), os.path.join(traj_ab, 'rgb'), '.jpg')   
    acopydir(os.path.join(traj_a, 'depth'), os.path.join(traj_b, 'depth'), os.path.join(traj_ab, 'depth'), '.npy')
    acopydir(os.path.join(traj_a, 'seg'), os.path.join(traj_b, 'seg'), os.path.join(traj_ab, 'seg'), '.npy')
    acopyjson(os.path.join(traj_a, 'data.json'), os.path.join(traj_b, 'data.json'), os.path.join(traj_ab, 'data.json'))
    
ctr = 1
for x in range(0, len(valid_traj), 2):
    a = valid_traj[x]
    b = valid_traj[x+1]
    if os.path.isdir(a) and os.path.isdir(b):
        print(f'combining {a} and {b}')
        combine(a, b, os.path.join(new_dir, str(ctr)))
        ctr += 1
# Out:
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/1 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/2
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/3 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/4
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/5 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/6
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/7 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/8
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/9 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/10
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/11 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/12
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/13 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/14
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/15 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/16
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/17 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/18
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/19 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/20
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/21 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/22
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/23 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/24
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/25 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/26
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/27 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/28
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/29 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/30
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/31 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/32
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/33 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/34
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/35 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/36
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/37 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/38
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/39 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/40
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/41 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/42
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/43 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/44
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/45 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/46
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/47 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/48
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/49 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/50
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/51 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/52
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/53 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/54
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/55 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/56
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/57 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/58
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/59 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/60
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/61 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/62
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/63 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/64
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/65 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/66
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/67 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/68
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/69 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/70
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/71 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/72
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/73 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/74
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/75 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/76
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/77 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/78
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/79 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/80
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/81 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/82
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/83 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/84
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/85 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/86
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/87 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/88
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/89 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/90
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/91 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/92
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/93 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/94
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/95 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/96
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/97 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/98
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/99 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/100
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/101 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/102
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/103 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/104
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/105 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/106
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/107 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/108
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/109 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/110
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/111 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/112
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/113 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/114
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/115 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/116
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/117 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/118
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/119 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/120
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/121 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/122
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/123 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/124
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/125 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/126
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/127 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/128
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/129 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/130
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/131 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/132
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/133 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/134
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/135 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/136
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/137 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/138
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/139 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/140
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/141 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/142
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/143 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/144
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/145 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/146
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/147 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/148
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/149 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/150
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/151 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/152
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/153 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/154
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/155 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/156
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/157 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/158
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/159 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/160
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/161 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/162
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/163 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/164
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/165 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/166
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/167 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/168
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/169 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/170
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/171 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/172
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/173 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/174
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/175 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/176
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/177 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/178
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/179 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/180
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/181 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/182
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/183 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/184
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/185 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/186
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/187 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/188
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/189 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/190
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/191 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/192
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/193 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/194
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/195 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/196
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/197 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/198
# combining /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/199 and /checkpoint/apratik/data/data/apartment_0/default/noise/mul_traj_200/200
