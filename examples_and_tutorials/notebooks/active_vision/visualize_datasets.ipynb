# %%
# vis_dir = '/checkpoint/apratik/jobs/active_vision/pipeline/apartment_0/default/no_noise/21-10-2021/05:54:36/2/pred_label_gt5p2/coco_visuals'

vis_dir = '/checkpoint/apratik/data_devfair0187/apartment_0/straightline/no_noise/1633991019/1/default/seg/coco_visuals/'

import os
import cv2
import matplotlib.pyplot as plt

for x in os.listdir(vis_dir):
    im = cv2.imread(os.path.join(vis_dir, x))
    plt.imshow(im)
    plt.show()
