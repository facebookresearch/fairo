# %% [markdown]
# - [x] sample nth frame for training / test split
# - [ ] create complete coco json using dhiraj's code
# - [ ] split it into training and test
# - [ ] retrain detector
# - [ ] take training set and do label prop to create training set augmented
# - [ ] retrain detector with this

# %%
import numpy as np
import sys
if '/opt/ros/kinetic/lib/python2.7/dist-packages' in sys.path:
    sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')

import cv2
import random
import os
import numpy as np
import json

# %% [markdown]
# # Sample Frames

# %%
sampled = open('/scratch/apratik/habitat_data_with_seg/sampled_imgs.txt','r') 
fs = [x.rsplit()[0] for x in sampled.readlines()]

# %%
print(fs[:3])
# Out:
# ['00000.jpg', '00060.jpg', '00120.jpg']

# %% [markdown]
# # Create coco json for fs

# %%
# helpfule for creating coco data based on the binary annotation images
from PIL import Image
import os
from pycococreatortools import pycococreatortools
import numpy as np
import cv2
from IPython import embed
import json

# Input ##
img_root_path = "/scratch/apratik/habitat_data_with_seg/rgb"
img_annot_root_path = "/scratch/apratik/habitat_data_with_seg/seg"
habitat_semantic_json = "/scratch/apratik/habitat_data_with_seg/info_semantic.json"
img_range = [0, 10]
###

with open(habitat_semantic_json, "r") as f:
    habitat_semantic_data = json.load(f)

INFO = {}

LICENSES = [{}]

# create categories out of it
CATEGORIES = []
for obj_cls in habitat_semantic_data["classes"]:
    CATEGORIES.append({"id": obj_cls["id"], "name": obj_cls["name"], "supercategory": "shape"})

coco_output = {
    "info": INFO,
    "licenses": LICENSES,
    "categories": CATEGORIES,
    "images": [],
    "annotations": [],
}

# %%
count = 0
for x in fs:
    image_id = int(x.split('.')[0])
    # load the annotation file
    try:
        annot = np.load(os.path.join(img_annot_root_path, "{:05d}.npy".format(image_id)))
    except:
        continue

    img_filename = "{:05d}.jpg".format(image_id)
    img = Image.open(os.path.join(img_root_path, img_filename))
    image_info = pycococreatortools.create_image_info(
        image_id, os.path.basename(img_filename), img.size
    )
    coco_output["images"].append(image_info)
    print("image_id = {}".format(image_id))

    # for each annotation add to coco format
    for i in np.unique(annot.reshape(-1), axis=0):
        try:
            category_info = {"id": habitat_semantic_data["id_to_label"][i], "is_crowd": False}
            if category_info["id"] < 1:
                continue
        except:
            print("label value doesnt exist for", i)
            continue
#         print(category_info)
        binary_mask = (annot == i).astype(np.uint8)

        annotation_info = pycococreatortools.create_annotation_info(
            count, image_id, category_info, binary_mask, img.size, tolerance=2
        )
        if annotation_info is not None:
            coco_output["annotations"].append(annotation_info)
            count += 1

with open("habitat_sem_annot.json", "w") as output_json:
    json.dump(coco_output, output_json)
# Out:
# image_id = 0
# label value doesnt exist for 4294967295
# image_id = 60
# label value doesnt exist for 4294967295
# image_id = 120
# image_id = 180
# image_id = 240
# image_id = 300
# image_id = 360
# image_id = 420
# image_id = 480
# image_id = 540
# image_id = 600
# image_id = 660
# image_id = 720
# image_id = 780
# image_id = 840
# image_id = 900
# image_id = 960
# image_id = 1020
# image_id = 1080
# image_id = 1140
# image_id = 1200
# image_id = 1260
# image_id = 1320
# image_id = 1380
# label value doesnt exist for 4294967295
# image_id = 1440
# label value doesnt exist for 4294967295
# image_id = 1500
# label value doesnt exist for 4294967295
# image_id = 1560
# label value doesnt exist for 4294967295
# image_id = 1620
# label value doesnt exist for 4294967295
# image_id = 1680
# image_id = 1740
# image_id = 1800
# image_id = 1860
# image_id = 1920
# image_id = 1980
# image_id = 2040
# label value doesnt exist for 4294967295
# image_id = 2100
# ...

# %%
for c in CATEGORIES:
    print(c['name'])
# Out:
# backpack
# base-cabinet
# basket
# bathtub
# beam
# beanbag
# bed
# bench
# bike
# bin
# blanket
# blinds
# book
# bottle
# box
# bowl
# camera
# cabinet
# candle
# chair
# chopping-board
# clock
# cloth
# clothing
# coaster
# comforter
# computer-keyboard
# cup
# cushion
# curtain
# ceiling
# cooktop
# countertop
# desk
# desk-organizer
# desktop-computer
# door
# exercise-ball
# faucet
# floor
# handbag
# hair-dryer
# handrail
# indoor-plant
# knife-block
# kitchen-utensil
# lamp
# laptop
# major-appliance
# mat
# microwave
# monitor
# mouse
# nightstand
# pan
# panel
# paper-towel
# phone
# picture
# pillar
# pillow
# pipe
# plant-stand
# plate
# pot
# rack
# refrigerator
# remote-control
# scarf
# sculpture
# shelf
# shoe
# shower-stall
# sink
# small-appliance
# sofa
# stair
# stool
# switch
# table
# table-runner
# tablet
# tissue-paper
# toilet
# toothbrush
# towel
# tv-screen
# tv-stand
# umbrella
# utensil-holder
# vase
# vent
# wall
# wall-cabinet
# wall-plug
# wardrobe
# ...

# %%
ceiling, floor, wall
from pycococreatortools import pycococreatortools
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-efde6f79ad50> in <module>
# ----> 1 ceiling, floor, wall
#       2 from pycococreatortools import pycococreatortools
#
# NameError: name 'ceiling' is not defined

# %%
pycococreatortools.
